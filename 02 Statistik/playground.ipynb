# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def simple_qq_plot_example(data):
  # Erstellen des QQ-Plots
  fig = plt.figure(figsize=(8, 6))
  ax = fig.add_subplot(111)
  stats.probplot(data, dist="norm", plot=ax)
  ax.get_lines()[1].set_color('red')  # Linie für die erwartete Normalverteilung hinzufügen (optional)
  plt.title('QQ-Plot')
  plt.xlabel('Theoretische Quantile')
  plt.ylabel('Beobachtete Quantile')
  plt.grid(True)
  plt.show()


# Beispiel Daten
np.random.seed(0)
data = np.random.normal(loc=0, scale=1, size=1000)
simple_qq_plot_example(data)

# %%
def median(values):
  n = len(values)
  return 1/2 * (values[(n-1)//2] + values[n//2])

def arith_mittel(values):
  return sum(values) / len(values)

# standard deviation
std = np.std(values)
# Out:
# 200
# (57.75, 57.6575, 3.7448556380720475)

# %%
import numpy as np
from scipy import stats

values = [47.5, 48.0, 48.5, 51.0, 51.5, 51.5, 52.5, 53.0, 53.0, 54.0, 54.0, 54.0, 55.0, 55.0, 55.0, 55.5, 55.5, 55.5, 56.0, 56.0, 56.0, 56.5, 56.5, 56.5, 57.0, 57.0, 57.0, 57.0,
          57.0, 57.0, 58.0, 58.0, 58.0, 58.5, 58.5, 58.5, 59.0, 59.0, 59.0, 59.0, 59.0, 59.0, 59.5, 59.5, 60.0, 60.5, 60.5, 60.5, 61.0, 61.0, 61.0, 61.5, 61.5, 61.5, 62.5, 62.5,
          63.0, 63.5, 64.0, 64.0, 49.5, 50.0, 50.0, 50.5, 52.0, 52.0, 52.0, 52.0, 53.0, 53.0, 53.0, 53.5, 54.0, 54.0, 54.5, 54.5, 55.0, 55.0, 55.0, 55.5, 55.5, 55.5, 55.5, 55.5,
          56.0, 56.0, 56.0, 56.0, 56.5, 56.5, 56.5, 56.5, 57.0, 57.0, 57.0, 57.0, 57.5, 57.5, 57.5, 57.5, 58.0, 58.0, 58.0, 58.0, 58.5, 58.5, 58.5, 58.5, 59.0, 59.0, 59.0, 59.0,
          59.0, 59.0, 59.5, 59.5, 60.0, 60.0, 60.0, 60.0, 60.5, 60.5, 60.5, 60.5, 61.0, 61.0, 61.0, 61.0, 62.0, 62.0, 62.0, 62.0, 63.0, 63.0, 63.0, 63.0, 64.0, 65.0, 65.0, 65.0,
50.5, 51.0, 51.0, 52.0, 52.5, 52.5, 53.5, 53.5, 53.5, 54.5, 54.5, 55.0, 55.5, 55.5, 55.5, 55.5, 55.5, 56.0, 56.0, 56.0, 56.5, 56.5, 56.5, 56.5, 57.0, 57.0, 57.0, 57.5, 57.5, 57.5,
58.0, 58.0, 58.5, 58.5, 58.5, 58.5, 59.0, 59.0, 59.0, 59.5, 59.5, 59.5, 60.0, 60.0, 60.0, 61.0, 61.0, 61.0, 61.0, 61.5, 61.5, 62.5, 62.5, 62.5, 63.5, 63.5, 63.5, 65.5, 67.0, 67.0]

n = len(values)
print(n)

median = 1/2 * (values[(n-1)//2] + values[n//2])

arith_mittel = np.sum(values) / len(values)

std = np.std(values)

median, arith_mittel, std
# Out:
# 200
# (57.75, 57.6575, 3.7448556380720475)

# %%
from utils import simple_plot
# simple_plot(values, median, std)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[421], line 1
# ----> 1 from utils import simple_plot
#       2 # simple_plot(values, median, std)
#
# File ~/Documents/Ausbildung : Kurse/CAS - Data Science/JupyterLab/02 Statistik/utils.py:67
#      64   plt.show()
#      66 # standard deviation
# ---> 67 std = np.std(values)
#
# NameError: name 'values' is not defined

# %%
# simple test simple_qq_plot_example
simple_qq_plot_example(values)
