# %%
import requests
import numpy as np
import pandas as pd
from pyproj import Transformer
from PIL import Image
import math

# %% [markdown]
# ## Search the geo.admin API

# %% [markdown]
# Find the official documentation here: https://api3.geo.admin.ch/
#
# You can use the search API of geo.admin (https://api3.geo.admin.ch/services/sdiservices.html#search) to find the location of addresses, zipcodes and more. Depending on what you search for, you might get more than one result, although the first result should be the most likely. Run the code and then try your own examples or the ones from the documentation in the link above.

# %%
_API_URL = 'https://api3.geo.admin.ch/rest/services/api/SearchServer'

# %%
def search_api_to_json(searchText, layer):
    url = f"{_API_URL}?type=locations&searchText={searchText}&origins={layer}"
    return requests.get(url).json()

# %%
#example
search_api_to_json('5070', 'zipcode')
# Out:
# {'results': [{'attrs': {'detail': '5070',
#     'featureId': '{80E4C1F5-1FE7-4D7F-B639-3DE19E1F1616}',
#     'geom_quadindex': '02111',
#     'geom_st_box2d': 'BOX(640651.1116166402 259870.9612737563,645784.5493048208 264245.921810695)',
#     'label': '<b>5070 - Frick</b>',
#     'lat': 47.50785827636719,
#     'lon': 8.011980056762695,
#     'num': 1,
#     'objectclass': '',
#     'origin': 'zipcode',
#     'rank': 1,
#     'x': 262058.4375,
#     'y': 643193.625,
#     'zoomlevel': 4294967295},
#    'id': 2814,
#    'weight': 100}]}

# %%
# dummy test
search_api_to_json('2814', 'id')
# Out:
# {'error': {'code': 400, 'message': "Bad value(s) in parameter origins 'id'"},
#  'success': False}

# %%
# example:
search_api_to_json('bahnhofstrasse 6 windisch', 'address')
# Out:
# {'results': [{'attrs': {'detail': 'bahnhofstrasse 6 5210 windisch 4123 windisch ch ag',
#     'featureId': '263003382_0',
#     'geom_quadindex': '021111313202212313313',
#     'geom_st_box2d': 'BOX(658212.8410884552 259285.88232247985,658212.8410884552 259285.88232247985)',
#     'label': 'Bahnhofstrasse 6 <b>5210 Windisch</b>',
#     'lat': 47.48176574707031,
#     'lon': 8.210972785949707,
#     'num': 6,
#     'objectclass': '',
#     'origin': 'address',
#     'rank': 7,
#     'x': 259285.875,
#     'y': 658212.8125,
#     'zoomlevel': 10},
#    'id': 1608860,
#    'weight': 7},
#   {'attrs': {'detail': 'bahnhofstrasse 6.2 5210 windisch 4123 windisch ch ag',
#     'featureId': '11002690_0',
#     'geom_quadindex': '021111313202210313231',
#     'geom_st_box2d': 'BOX(658210.6560419576 259314.4481761479,658210.6560419576 259314.4481761479)',
#     'label': 'Bahnhofstrasse 6.2 <b>5210 Windisch</b>',
#     'lat': 47.48202133178711,
#     'lon': 8.210947036743164,
#     'num': 62,
#     'objectclass': '',
#     'origin': 'address',
#     'rank': 7,
#     'x': 259314.453125,
#     'y': 658210.625,
#     'zoomlevel': 10},
#    'id': 1155313,
#    'weight': 4},
#   {'attrs': {'detail': 'bahnhofstrasse 6a 5210 windisch 4123 windisch ch ag',
#     'featureId': '263003382_3',
#     'geom_quadindex': '021111313202231010230',
#     'geom_st_box2d': 'BOX(658221.2580703201 259274.54143489752,658221.2580703201 259274.54143489752)',
#     'label': 'Bahnhofstrasse 6a <b>5210 Windisch</b>',
#     'lat': 47.48166275024414,
#     'lon': 8.211082458496094,
#     'num': 6,
#     'objectclass': '',
#     'origin': 'address',
#     'rank': 7,
#     'x': 259274.546875,
#     'y': 658221.25,
#     'zoomlevel': 10},
#    'id': 1704266,
#    'weight': 2},
#   {'attrs': {'detail': 'bahnhofstrasse 6a.1 5210 windisch 4123 windisch ch ag',
#     'featureId': '263105781_0',
#     'geom_quadindex': '021111313202321101232',
#     'geom_st_box2d': 'BOX(658291.0040290091 259273.76882561902,658291.0040290091 259273.76882561902)',
#     'label': 'Bahnhofstrasse 6a.1 <b>5210 Windisch</b>',
#     'lat': 47.481651306152344,
#     'lon': 8.212007522583008,
#     'num': 61,
#     'objectclass': '',
#     'origin': 'address',
#     'rank': 7,
#     'x': 259273.765625,
#     'y': 658291.0,
#     'zoomlevel': 10},
#    'id': 2503427,
#    'weight': 1},
#   {'attrs': {'detail': 'bahnhofstrasse 6a.2 5210 windisch 4123 windisch ch ag',
#     'featureId': '263105782_0',
#     'geom_quadindex': '021111313202330202021',
#     'geom_st_box2d': 'BOX(658301.6899941708 259257.6599814857,658301.6899941708 259257.6599814857)',
#     'label': 'Bahnhofstrasse 6a.2 <b>5210 Windisch</b>',
#     'lat': 47.481502532958984,
#     'lon': 8.21214771270752,
#     'num': 62,
#     'objectclass': '',
#     'origin': 'address',
#     'rank': 7,
#     'x': 259257.65625,
#     'y': 658301.6875,
#     'zoomlevel': 10},
#    'id': 2484678,
#    'weight': 1}]}

# %% [markdown]
# ## Format Conversion

# %% [markdown]
# Format conversion can be a bit tricky - trying it yourself is futile, but fortunately there are python packages available. To find the name of the location formats, go see https://epsg.io/

# %%
def from_latitude_longitude_to_e_n(lat: float, long: float):
    transformer = Transformer.from_crs("epsg:4326", "epsg:2056")
    return transformer.transform(lat, long)

# %%
def from_e_n_to_latitude_longitude(e: float, n: float):
    transformer = Transformer.from_crs("epsg:2056", "epsg:4326")
    return transformer.transform(e, n)

# %%
def from_lv03_to_lv95(x: float, y: float):
    """Not an exact transformation, but a good aproximation"""
    e = y + 2000000
    n = x + 1000000
    return e,n

# %% [markdown]
# ## GIS images

# %% [markdown]
# You can also use the API to search for images. To define how big the cutout is that you cant, it is easier to avoid using latitude / longitude.

# %%
def get_gis_image_url(e, n, radius, layers):
    l_e, r_e, t_n, b_n = e - radius, e + radius, n - radius, n + radius
    return f"https://wms.geo.admin.ch/?SERVICE=WMS&VERSION=1.3.0&REQUEST=GetMap&FORMAT=image%2Fpng&TRANSPARENT=false&LAYERS={','.join(layers)}&WIDTH={256}&HEIGHT={256}&CRS=epsg%3A2056&STYLES=&BBOX={l_e}%2C{t_n}%2C{r_e}%2C{b_n}"

# %%
latitude, longitude = 47.48196574707031, 8.211122785949707
e, n = from_latitude_longitude_to_e_n(latitude, longitude)
image_url = get_gis_image_url(e, n, 250, ['ch.kantone.cadastralwebmap-farbe'])

# %%
img = Image.open(requests.get(image_url, stream=True).raw)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=256x256>

# %%
# layer = 'ch.are.bauzonen'
# layer = 'ch.kantone.cadastralwebmap-farbe'
layer = 'ch.bafu.laerm-strassenlaerm_tag'

res = search_api_to_json('Gänsacker 1 5070 Frick', 'address')
attrs = res['results'][0]['attrs']
# print(res['results'][0]['attrs'])
latitude, longitude = attrs['lat'], attrs['lon']

# # latitude, longitude = 47.50785827636719, 8.011980056762695
e, n = from_latitude_longitude_to_e_n(latitude, longitude)
image_url = get_gis_image_url(e, n, 350, [layer])

img = Image.open(requests.get(image_url, stream=True).raw)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=256x256>

# %% [markdown]
# ## Exercise Cleaning GeoData

# %% [markdown]
# You have a dataset with a column that just says "location". It contains addresses, longitude / latitude (sometimes in the wrong order) and coordinates in the LV95  format. You do know however, that all locations are supposed to be somewhere in Switzerland (so a latitude between 45 and 48 and longitude between 5 and 11). Write a function that takes this undefined input and given longitude and latitude as output. Then apply this function to the dataset to get two new columns.

# %%
df = pd.read_excel("locations.xlsx")
df
# Out:
#                                   location      Country  measurement
# 0                       46.585607,7.785153           CH          9.3
# 1                       46.746794,8.651131           CH         69.7
# 2                     47.165476, 7.071886            CH         68.4
# 3                       46.933067,8.600839      Schweiz         64.8
# 4                         2657474, 1257432           CH         50.9
# 5                         2659831, 1256123           CH         40.1
# 6                           5210, Windisch  Switzerland         47.5
# 7                     "46.688389,8.866704"           CH         15.8
# 8                       47.612133,8.380114      Schweiz         15.4
# 9                      8.917436,46.460269,           CH         95.3
# 10                      Bundesgasse 8 Bern      Schweiz         51.5
# 11              bahnhofstrasse 6, windisch           CH         13.8
# 12                        46.958475,6.8798           CH         95.4
# 13                     10.465918,47.104246           CH         65.3
# 14                            Bern Bahnhof           CH         55.6
# 15                    "46.33367,10.032601"           CH         39.7
# 16                      47.097346,9.569649           CH         92.7
# 17          lat: 46.757079, long: 10.27714  Switzerland         87.2
# 18                      46.352582,7.054364           CH         26.5
# 19                       47.464724,7.44805           CH         91.8
# 20                                    Genf           CH         41.2
# 21                       47.723148,8.18907           DE         93.9
# 22                      47.917336,8.203725  Deutschland         55.9
# 23  2658494.4007178904, 1259314.8490574476           CH         71.2
# 24                      47.032268,8.719771           FR         41.9
# 25                      47.071884,9.838366           CH         71.2
# 26                      8.183954,46.243159      Somalia         95.1
# 27                      47.516001,7.230788           CH         51.0
# 28                      46.771915,6.657048           CH         74.0
# 29                      46.460269,8.917436           CH         95.3

# %%
def extract_lat_long(x):
    # TODO: this code is to get you started and will convert many of the values in this dataframe correctly. 
    # Expand this function with more functionality, to automatically convert as many entries as possible to the
    # correct latitude and longitude values.
    latlong = x.split(',')
    if(len(latlong) == 2):
        

        try:
            float(latlong[0])
        except ValueError:
          res = search_api_to_json(latlong[0] + latlong[1], 'address')
          if (len(res['results']) == 0):
              return 0,0
          attrs = res['results'][0]['attrs']
          latitude, longitude = attrs['lat'], attrs['lon']
          return latitude,longitude

        if (math.isnan(float(latlong[0]))):
            return 0,0
        
        # match if starting with 26
        if(latlong[0].startswith('26')):
            return from_e_n_to_latitude_longitude(float(latlong[0]), float(latlong[1]))

        return latlong[0], latlong[1]
    return 0,0

# %%
# applies the function above to the location field in the dataframe and adds two new columns lat and long
df["lat"], df["long"] = zip(*df["location"].map(extract_lat_long))
df
# Out:
#                                   location      Country  measurement  \
# 0                       46.585607,7.785153           CH          9.3
# 1                       46.746794,8.651131           CH         69.7
# 2                     47.165476, 7.071886            CH         68.4
# 3                       46.933067,8.600839      Schweiz         64.8
# 4                         2657474, 1257432           CH         50.9
# 5                         2659831, 1256123           CH         40.1
# 6                           5210, Windisch  Switzerland         47.5
# 7                     "46.688389,8.866704"           CH         15.8
# 8                       47.612133,8.380114      Schweiz         15.4
# 9                      8.917436,46.460269,           CH         95.3
# 10                      Bundesgasse 8 Bern      Schweiz         51.5
# 11              bahnhofstrasse 6, windisch           CH         13.8
# 12                        46.958475,6.8798           CH         95.4
# 13                     10.465918,47.104246           CH         65.3
# 14                            Bern Bahnhof           CH         55.6
# 15                    "46.33367,10.032601"           CH         39.7
# 16                      47.097346,9.569649           CH         92.7
# 17          lat: 46.757079, long: 10.27714  Switzerland         87.2
# 18                      46.352582,7.054364           CH         26.5
# 19                       47.464724,7.44805           CH         91.8
# 20                                    Genf           CH         41.2
# 21                       47.723148,8.18907           DE         93.9
# 22                      47.917336,8.203725  Deutschland         55.9
# 23  2658494.4007178904, 1259314.8490574476           CH         71.2
# 24                      47.032268,8.719771           FR         41.9
# 25                      47.071884,9.838366           CH         71.2
# 26                      8.183954,46.243159      Somalia         95.1
# 27                      47.516001,7.230788           CH         51.0
# 28                      46.771915,6.657048           CH         74.0
# 29                      46.460269,8.917436           CH         95.3
#
#            lat        long
# 0    46.585607    7.785153
# 1    46.746794    8.651131
# 2    47.165476   7.071886
# 3    46.933067    8.600839
# 4    47.465156     8.20092
# 5    47.453174    8.232004
# 6         5210    Windisch
# 7            0           0
# 8    47.612133    8.380114
# 9            0           0
# 10           0           0
# 11   47.481766    8.210973
# 12   46.958475      6.8798
# 13   10.465918   47.104246
# 14           0           0
# 15           0           0
# 16   47.097346    9.569649
# 17           0           0
# 18   46.352582    7.054364
# 19   47.464724     7.44805
# 20           0           0
# 21   47.723148     8.18907
# 22   47.917336    8.203725
# 23      47.482      8.2147
# 24   47.032268    8.719771
# 25   47.071884    9.838366
# 26    8.183954   46.243159
# 27   47.516001    7.230788
# 28   46.771915    6.657048
# 29   46.460269    8.917436
