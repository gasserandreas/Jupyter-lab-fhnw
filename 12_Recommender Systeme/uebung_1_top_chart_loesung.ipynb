# %% [markdown]
# # Übung 1 - Simple Recommender System
#
# In der 1. Übung implementieren wir ein einfaches Recommender System, welches nur allgemein gültige Vorschläge macht - sprich keine personalisierte Vorschläge für jeden Benutzer.
# Für die Übungen verwenden wir [The Movies Dataset](https://www.kaggle.com/rounakbanik/the-movies-dataset?select=movies_metadata.csv), welcher für die [MovieLens](https://grouplens.org/datasets/movielens/) Rating auch noch Meta-Daten von der [The Movie Database (TMDb)](https://www.themoviedb.org/) der Filme enthält.

# %%
import pandas as pd
import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# Einlesen der Meta-Daten aller Filme

# %%
movies = pd.read_csv('data/movies_all.csv')[['title', 'genres', 'vote_average', 'vote_count']]
movies.head()
# Out:
#                  title                                             genres  \
# 0            Inception  ['Action', 'Thriller', 'Science Fiction', 'Mys...
# 1      The Dark Knight           ['Drama', 'Action', 'Crime', 'Thriller']
# 2               Avatar  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 3  The Avengers (2012)         ['Science Fiction', 'Action', 'Adventure']
# 4             Deadpool                  ['Action', 'Adventure', 'Comedy']
#
#    vote_average  vote_count
# 0           8.1       14075
# 1           8.3       12269
# 2           7.2       12114
# 3           7.4       12000
# 4           7.4       11444

# %% [markdown]
# ## 1. Top-Listen

# %% [markdown]
# Die einfachste Art die Besten Filme zu finden, ist einfach die Liste nach dem durchschnittlichen Rating zu sortieren und die besten auszugeben.\
# Hinweis: [pandas.DataFrame.sort_values](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html)

# %%
# Sortiere die Filme nach `vote_average` und gebe die Top 10 aus.
movies.sort_values('vote_average', ascending=False).head(10)
# Out:
#                                                    title  \
# 40794  Old Fashioned: The Story of the Wisconsin Supp...
# 42301                                             Mammal
# 41716                                   Dragonfly (1976)
# 42232                                            Firefly
# 40939                        Kenny Chesney: Summer In 3D
# 40482                                     My Future Love
# 40485             Big Jay Oakerson: Live at Webster Hall
# 40920                                  OMG, I'm a Robot!
# 39308                                  The Danube Exodus
# 40892          If God Is Willing and da Creek Don't Rise
#
#                               genres  vote_average  vote_count
# 40794     ['Documentary', 'History']          10.0           1
# 42301                      ['Drama']          10.0           1
# 41716                      ['Drama']          10.0           1
# 42232                     ['Comedy']          10.0           1
# 40939                             []          10.0           1
# 40482            ['Comedy', 'Drama']          10.0           1
# 40485                     ['Comedy']          10.0           1
# 40920  ['Comedy', 'Science Fiction']          10.0           1
# 39308                ['Documentary']          10.0           1
# 40892                ['Documentary']          10.0           1

# %%
movies.sort_values(['vote_average', 'vote_count'], ascending=False).head(10)
# Out:
#                                                   title  \
# 33494                                            Avetik
# 33561                                            Maidan
# 34036  Frankie Boyle: Hurt Like You've Never Been Loved
# 35677                                   Mera Naam Joker
# 35686                                  Butterfly (2015)
# 36354                                        Redemption
# 36715                                    The Little Hut
# 36842                               Survive and Advance
# 36940             LEGO DC Super Hero Girls: Brain Drain
# 37014                                      Patient Zero
#
#                                                   genres  vote_average  \
# 33494                                          ['Drama']          10.0
# 33561                                    ['Documentary']          10.0
# 34036                                         ['Comedy']          10.0
# 35677                               ['Drama', 'Romance']          10.0
# 35686  ['Science Fiction', 'Drama', 'Fantasy', 'Roman...          10.0
# 36354                                        ['History']          10.0
# 36715                              ['Comedy', 'Romance']          10.0
# 36842                                                 []          10.0
# 36940                                      ['Animation']          10.0
# 37014          ['Action', 'Drama', 'Horror', 'Thriller']          10.0
#
#        vote_count
# 33494           3
# 33561           3
# 34036           3
# 35677           3
# 35686           3
# 36354           2
# 36715           2
# 36842           2
# 36940           2
# 37014           2

# %% [markdown]
# Was fällt auf? Es gibt Filme mit nur einer 10er-Bewertung, welche nun zuoberst sind. Das wollen wir natürlich nicht. Auch wenn wir noch zusätzlich nach `vote_count` sortieren, wird es nicht besser.

# %% [markdown]
# IMDB verwendet für ihre Top-Charts ein gewichtet Rating, welches folgendermassen definiert ist:
#
# Weighted Rating (WR) = $(\frac{v}{v + m} . R) + (\frac{m}{v + m} . C)$
#
# * *v* := Anzahl Stimmen
# * *m* := Minimum Anzahl Stimmen um auf die Liste zu kommen
# * *R* := Durchschnittliches Rating des Filmes
# * *C* := Durchschnittliches Rating aller Filme
#
# Lasst uns nun das durchschnittliche Rating aller Filme (C) berechnen und ein Minimum Anzahl Stimmen (m) definieren.

# %%
# Berechne das durchschnittle Rating aller Filme
C = movies['vote_average'].mean()
C
# Out:
# 5.618217011635836

# %% [markdown]
# Hinweis: [pandas.DataFrame.quantile](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.quantile.html)

# %%
# Lasst uns das 95ste Quantile als minimale Anzahl Stimmen definieren. Sprich die Filme auf unsere Top-Liste sollen mehr Stimmen haben, als 95% aller Filme.
m = movies['vote_count'].quantile(0.95)
m
# Out:
# 433.90000000000146

# %% [markdown]
# Jetzt können wir noch die Funktion für das Gewichtete Rating definieren und anschliessend unsere Top-Liste berechnen.

# %%
# Definiere das Gewichtete Rating (x := Zeile des DataFrame)
def weighted_rating(x, m, C):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m) * R) + (m/(v+m) * C)

# %% [markdown]
# Hinweis: [pandas.DataFrame.apply](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html)

# %%
# Gewichtetes Rating berechnen und einer neuen Spalte zuweisen anschliessend
movies['wr'] = movies.apply(weighted_rating, m=m, C=C, axis=1)

# %%
# Variante ohne apply
v = movies['vote_count']
R = movies['vote_average']
movies['wr'] = (v/(v+m) * R) + (m/(v+m) * C)

# %%
# sortiere das Dataframe nach dem gewichteten Rating und gebe die Top-20 Filme aus
movies.sort_values('wr', ascending=False).head(20)
# Out:
#                                              title  \
# 19                        The Shawshank Redemption
# 61                                   The Godfather
# 1                                  The Dark Knight
# 8                                       Fight Club
# 17                                    Pulp Fiction
# 21                                    Forrest Gump
# 149                               Schindler's List
# 152                                       Whiplash
# 180                                  Spirited Away
# 63                         The Empire Strikes Back
# 0                                        Inception
# 208                              Life Is Beautiful
# 88                                The Intouchables
# 5                                     Interstellar
# 230                         The Godfather: Part II
# 20   The Lord of the Rings: The Return of the King
# 155                         Leon: The Professional
# 294                One Flew Over the Cuckoo's Nest
# 166                                 The Green Mile
# 37                                       Star Wars
#
#                                                 genres  vote_average  \
# 19                                  ['Drama', 'Crime']           8.5
# 61                                  ['Drama', 'Crime']           8.5
# 1             ['Drama', 'Action', 'Crime', 'Thriller']           8.3
# 8                                            ['Drama']           8.3
# 17                               ['Thriller', 'Crime']           8.3
# 21                      ['Comedy', 'Drama', 'Romance']           8.2
# 149                        ['Drama', 'History', 'War']           8.3
# 152                                          ['Drama']           8.3
# 180    ['Fantasy', 'Adventure', 'Animation', 'Family']           8.3
# 63          ['Adventure', 'Action', 'Science Fiction']           8.2
# 0    ['Action', 'Thriller', 'Science Fiction', 'Mys...           8.1
# 208                                ['Comedy', 'Drama']           8.3
# 88                                 ['Drama', 'Comedy']           8.2
# 5            ['Adventure', 'Drama', 'Science Fiction']           8.1
# 230                                 ['Drama', 'Crime']           8.3
# 20                  ['Adventure', 'Fantasy', 'Action']           8.1
# 155                     ['Thriller', 'Crime', 'Drama']           8.2
# 294                                          ['Drama']           8.3
# 166                      ['Fantasy', 'Drama', 'Crime']           8.2
# 37          ['Adventure', 'Action', 'Science Fiction']           8.1
#
#      vote_count        wr
# 19         8358  8.357778
# 61         6024  8.306376
# 1         12269  8.208397
# 8          9678  8.184925
# 17         8670  8.172184
# 21         8147  8.069450
# 149        4436  8.061058
# 152        4376  8.058077
# 180        3968  8.035654
# 63         5998  8.025831
# 0         14075  8.025780
# 208        3643  8.014581
# 88         5410  8.008307
# 5         11187  8.007335
# 230        3418  7.997909
# 20         8226  7.975651
# 155        4293  7.963008
# 294        3001  7.961234
# 166        4166  7.956465
# 37         6778  7.950685

# %% [markdown]
# Das sieht schon etwas besser au. Jedoch fällt auf das vor allem Dramen und Thriller zuoberst auf der Liste stehen, und keine Romanzen unter die Top-20 geschafft haben.

# %% [markdown]
# ## Top-Genre-Liste

# %% [markdown]
# Darum werden wir im nächsten Schritt nun Top-Listen pro Genre erstellen.\
# Hinweis: [pandas.Series.str.contains](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.contains.html)

# %%
# Implementiere nun folgende Funktion welche für ein bestimmtes Genre die Top-Liste zurückgibt 
def top_genre_chart(movies, genre, percentile=0.85):
    movies_genre = movies[movies.genres.str.contains(genre, regex=False)]
    C = movies_genre['vote_average'].mean()
    m = movies_genre['vote_count'].quantile(percentile)

    movies_genre['wr'] = movies_genre.apply(weighted_rating, args=(m, C), axis=1)
    movies_genre = movies_genre.sort_values('wr', ascending=False).head(250)
    
    return movies_genre

# %%
# Gebe nun die Top-20 Romance-Filme aus
top_genre_chart(movies, 'Romance').head(20)
# Out:
#                                       title  \
# 1635            Dilwale Dulhania Le Jayenge
# 1087                             Your Name.
# 21                             Forrest Gump
# 1349                        Cinema Paradiso
# 121                              La La Land
# 160                                     Her
# 202   Eternal Sunshine of the Spotless Mind
# 966                                 Vertigo
# 2235                            City Lights
# 669                              Mr. Nobody
# 694                       Captain Fantastic
# 1347                       Some Like It Hot
# 765                              Casablanca
# 1488                               Paperman
# 232         The Theory of Everything (2014)
# 233                                  Amélie
# 2057                          The Apartment
# 1617                            Sing Street
# 2201                         The Handmaiden
# 802                       Pride & Prejudice
#
#                                                  genres  vote_average  \
# 1635                     ['Comedy', 'Drama', 'Romance']           9.1
# 1087                  ['Romance', 'Animation', 'Drama']           8.5
# 21                       ['Comedy', 'Drama', 'Romance']           8.2
# 1349                               ['Drama', 'Romance']           8.2
# 121             ['Comedy', 'Drama', 'Music', 'Romance']           7.9
# 160             ['Romance', 'Science Fiction', 'Drama']           7.9
# 202             ['Science Fiction', 'Drama', 'Romance']           7.9
# 966                  ['Mystery', 'Romance', 'Thriller']           8.0
# 2235                     ['Comedy', 'Drama', 'Romance']           8.2
# 669   ['Science Fiction', 'Drama', 'Romance', 'Fanta...           7.9
# 694         ['Adventure', 'Comedy', 'Drama', 'Romance']           7.9
# 1347                              ['Comedy', 'Romance']           8.0
# 765                                ['Drama', 'Romance']           7.9
# 1488                 ['Animation', 'Family', 'Romance']           8.0
# 232                                ['Drama', 'Romance']           7.8
# 233                               ['Comedy', 'Romance']           7.8
# 2057                     ['Comedy', 'Drama', 'Romance']           8.1
# 1617                      ['Romance', 'Drama', 'Music']           8.0
# 2201                   ['Thriller', 'Drama', 'Romance']           8.1
# 802                                ['Drama', 'Romance']           7.8
#
#       vote_count        wr
# 1635         661  8.701372
# 1087        1030  8.281258
# 21          8147  8.173547
# 1349         834  7.964387
# 121         4745  7.860576
# 160         4215  7.855724
# 202         3758  7.850467
# 966         1162  7.840579
# 2235         444  7.792600
# 669         1616  7.788307
# 694         1569  7.785145
# 1347         835  7.784276
# 765         1462  7.777231
# 1488         734  7.757863
# 232         3403  7.748036
# 233         3403  7.748036
# 2057         498  7.745392
# 1617         669  7.737152
# 2201         453  7.716054
# 802         1406  7.678710
