# %% [markdown]
# # Übung 4 - Matrix Faktorisierung

# %% [markdown]
# In dieser Übung verwenden wir die Library [Surprise](http://surpriselib.com/) um ein Matrix Faktorisierungs Model zu trainieren

# %%
import numpy as np
import pandas as pd
from surprise import Dataset, Reader, SVD

import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# ## Einlesen der Daten

# %%
movies = pd.read_csv('data/movies.csv')
movies = movies[['movieId', 'title']]

# %%
ratings = pd.read_csv('data/ratings.csv')

# %%
# verwerfen aller Film mit weniger als 25 ratings
ratings = ratings.groupby('movieId').filter(lambda x: x['movieId'].count() > 25)

# movieIds anpassen
movies = movies[movies.movieId.isin(set(ratings.movieId))].reset_index(drop=True)
ratings['movieId'] = ratings.movieId.map({mi: i for i, mi in movies.movieId.items()})
movies['movieId'] = movies.movieId.map({mi: i for i, mi in movies.movieId.items()})

# %% [markdown]
# Daten in Dataset von Surprise laden\
# Hinweis: [Getting Started - dataset from a pandas dataframe](https://surprise.readthedocs.io/en/stable/getting_started.html?highlight=Reader#load-dom-dataframe-py)

# %%
# dataset einlesen
reader = Reader(rating_scale=(1, 5))
dataset = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)

# %% [markdown]
# Jetzt erstellen wir das trainset und testset\
# Hinweis:\
# [surprise.dataset.DatasetAutoFolds.build_full_trainset](https://surprise.readthedocs.io/en/stable/dataset.html#surprise.dataset.DatasetAutoFolds.build_full_trainset)\
# [surprise.Trainset.build_anti_testset](https://surprise.readthedocs.io/en/stable/trainset.html#surprise.Trainset.build_anti_testset)\
# [surprise.Trainset.build_testset](https://surprise.readthedocs.io/en/stable/trainset.html#surprise.Trainset.build_testset)

# %%
# trainset erstellen
trainset = dataset.build_full_trainset()
# testset erstellen aus anti-testset (alle fehlende Bewertungen) + testset aus trainset
testset = trainset.build_anti_testset() + trainset.build_testset()

# %% [markdown]
# Nun können wir die Matrix Faktorisierung berechnen und Vorschläge generieren\
# Hinweis:
# [how-to-get-the-top-n-recommendations-for-each-user](https://surprise.readthedocs.io/en/stable/FAQ.html#how-to-get-the-top-n-recommendations-for-each-user)

# %%
# recommender initialisieren und trainieren
recommender = SVD(n_factors=150, n_epochs=100)
recommender.fit(trainset)

# %%
# alle predictions machen und in einem DataFrame mit den Filenamen mergen
recommendations = pd.DataFrame(recommender.test(testset))
recommendations = recommendations.merge(movies, left_on='iid', right_on='movieId')

# %%
ratings.sort_values(['userId', 'movieId'])
# Out:
#        userId  movieId  rating   timestamp  \
# 6           0      358     2.0  1260759108
# 18          0      384     3.0  1260759179
# 14          0      411     3.5  1260759125
# 5           0      426     2.5  1260759113
# 8           0      464     2.0  1260759151
# ...       ...      ...     ...         ...
# 99714     670      891     3.0  1064891236
# 99756     670      961     2.5  1063503739
# 99720     670      965     4.0  1064891534
# 99744     670      969     4.0  1063502750
# 99770     670      990     4.0  1063503933
#
#                                               title
# 6                                              Antz
# 18                                            Dumbo
# 14                                          Dracula
# 5                                    The Fly (1986)
# 8                                   The Deer Hunter
# ...                                             ...
# 99714                               A Grand Day Out
# 99756  City Slickers II: The Legend of Curly's Gold
# 99720                   Searching for Bobby Fischer
# 99744                                    Roger & Me
# 99770                                    Waking Ned
#
# [62227 rows x 5 columns]

# %%
recommendations.sort_values(['uid', 'iid']).head(20)
# Out:
#         uid  iid      r_ui       est                    details  movieId  \
# 285175    0    0  3.669661  3.059559  {'was_impossible': False}        0
# 54351     0    1  3.669661  3.425769  {'was_impossible': False}        1
# 455609    0    2  3.669661  2.821915  {'was_impossible': False}        2
# 540155    0    3  3.669661  2.461706  {'was_impossible': False}        3
# 334829    0    4  3.669661  2.927700  {'was_impossible': False}        4
# 559614    0    5  3.669661  3.059636  {'was_impossible': False}        5
# 348920    0    6  3.669661  2.389299  {'was_impossible': False}        6
# 57706     0    7  3.669661  3.171762  {'was_impossible': False}        7
# 284504    0    8  3.669661  2.762307  {'was_impossible': False}        8
# 341539    0    9  3.669661  2.848403  {'was_impossible': False}        9
# 283833    0   10  3.669661  2.698402  {'was_impossible': False}       10
# 215391    0   11  3.669661  3.305825  {'was_impossible': False}       11
# 446215    0   12  3.669661  3.056431  {'was_impossible': False}       12
# 236863    0   13  3.669661  2.883860  {'was_impossible': False}       13
# 2684      0   14  3.669661  3.486279  {'was_impossible': False}       14
# 55693     0   15  3.669661  3.327202  {'was_impossible': False}       15
# 50996     0   16  3.669661  2.951172  {'was_impossible': False}       16
# 12749     0   17  3.669661  2.959879  {'was_impossible': False}       17
# 342881    0   18  3.669661  2.479058  {'was_impossible': False}       18
# 46299     0   19  3.669661  2.846547  {'was_impossible': False}       19
#
#                                                     title
# 285175                                          Inception
# 54351                                     The Dark Knight
# 455609                                             Avatar
# 540155                                The Avengers (2012)
# 334829                                       Interstellar
# 559614                                   Django Unchained
# 348920                            Guardians of the Galaxy
# 57706                                          Fight Club
# 284504                                   The Hunger Games
# 341539                                 Mad Max: Fury Road
# 283833                              The Dark Knight Rises
# 215391                                         The Matrix
# 446215                                           Iron Man
# 236863  The Lord of the Rings: The Fellowship of the Ring
# 2684                                         Pulp Fiction
# 55693                            The Shawshank Redemption
# 50996       The Lord of the Rings: The Return of the King
# 12749                                        Forrest Gump
# 342881                       Star Wars: The Force Awakens
# 46299                                             Titanic

# %%
# Ratings eines User ausgeben
user_id = 45
ratings[ratings.userId == user_id].sort_values('rating', ascending=False).head(20)
# Out:
#       userId  movieId  rating   timestamp  \
# 7286      45       78     5.0  1366393308
# 7287      45      725     5.0  1366389683
# 7320      45       20     5.0  1366391137
# 7319      45      754     5.0  1366391610
# 7316      45      939     5.0  1366389759
# 7315      45       46     5.0  1366393591
# 7314      45      601     5.0  1366389699
# 7313      45      647     5.0  1366389671
# 7311      45       16     5.0  1366390910
# 7310      45       34     5.0  1366392989
# 7309      45      133     5.0  1366389926
# 7308      45       36     5.0  1366392165
# 7302      45       13     5.0  1366390915
# 7301      45      623     5.0  1366392410
# 7300      45      121     5.0  1366393535
# 7299      45      433     5.0  1366389737
# 7298      45        1     5.0  1366390187
# 7297      45      499     5.0  1366389694
# 7293      45        3     5.0  1366391603
# 7292      45        0     5.0  1366390899
#
#                                                   title
# 7286                                        Ratatouille
# 7287                                          The Craft
# 7320              The Lord of the Rings: The Two Towers
# 7319                                  A Christmas Story
# 7316                                           Repo Man
# 7315       Harry Potter and the Deathly Hallows: Part 1
# 7314                                         Entrapment
# 7313                                       Analyze This
# 7311      The Lord of the Rings: The Return of the King
# 7310                                 Back to the Future
# 7309                                         Madagascar
# 7308       Harry Potter and the Deathly Hallows: Part 2
# 7302  The Lord of the Rings: The Fellowship of the Ring
# 7301                                    The Flintstones
# 7300                                 The Social Network
# 7299     The Naked Gun: From the Files of Police Squad!
# 7298                                    The Dark Knight
# 7297                                   Cruel Intentions
# 7293                                The Avengers (2012)
# 7292                                          Inception

# %%
# Recommendations für einen User ausgeben
recommendations[recommendations.uid == user_id].sort_values('est', ascending=False).head(20)
# Out:
#         uid  iid      r_ui  est                    details  movieId  \
# 666345   45  509  3.669661  5.0  {'was_impossible': False}      509
# 465045   45  123  3.669661  5.0  {'was_impossible': False}      123
# 436194   45  129  3.669661  5.0  {'was_impossible': False}      129
# 439547   45   29  3.669661  5.0  {'was_impossible': False}       29
# 440890   45  252  3.669661  5.0  {'was_impossible': False}      252
# 184560   45  418  3.669661  5.0  {'was_impossible': False}      418
# 181208   45   67  3.669661  5.0  {'was_impossible': False}       67
# 445587   45  346  3.669661  5.0  {'was_impossible': False}      346
# 179863   45  126  3.669661  5.0  {'was_impossible': False}      126
# 179197   45  293  3.669661  5.0  {'was_impossible': False}      293
# 177853   45  496  3.669661  5.0  {'was_impossible': False}      496
# 177182   45  549  3.669661  5.0  {'was_impossible': False}      549
# 446256   45   12  3.669661  5.0  {'was_impossible': False}       12
# 448941   45  136  3.669661  5.0  {'was_impossible': False}      136
# 173825   45  108  3.669661  5.0  {'was_impossible': False}      108
# 456989   45  393  3.669661  5.0  {'was_impossible': False}      393
# 458335   45   84  3.669661  5.0  {'was_impossible': False}       84
# 459677   45  150  3.669661  5.0  {'was_impossible': False}      150
# 461692   45  231  3.669661  5.0  {'was_impossible': False}      231
# 190600   45  225  3.669661  5.0  {'was_impossible': False}      225
#
#                                       title
# 666345                      Cinema Paradiso
# 465045                           District 9
# 436194  The Curious Case of Benjamin Button
# 439547                 Inglourious Basterds
# 440890                                 Moon
# 184560                         Office Space
# 181208                      The Truman Show
# 445587                            Zoolander
# 179863               The Godfather: Part II
# 179197              The Godfather: Part III
# 177853                         The Graduate
# 177182                      Erin Brockovich
# 446256                             Iron Man
# 448941                        Kung Fu Panda
# 173825                Ocean's Eleven (2001)
# 456989           O Brother, Where Art Thou?
# 458335             How to Train Your Dragon
# 459677                              Shrek 2
# 461692                    National Treasure
# 190600                         The Exorcist
